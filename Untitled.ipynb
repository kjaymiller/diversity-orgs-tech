# %%
import pandas as pd
from fuzzywuzzy import process, fuzz
# Out:
# /Users/kjaymiller/.pyenv/versions/3.9.1/envs/diversity/lib/python3.9/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
df = pd.read_json('diversityorgs.tech.json').fillna('')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 494 entries, 0 to 493
# Data columns (total 17 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   name                                     494 non-null    object
#  1   url                                      494 non-null    object
#  2   links                                    494 non-null    object
#  3   technology_focus                         494 non-null    object
#  4   organization_logo                        494 non-null    object
#  5   id                                       494 non-null    object
#  6   diversity_focus                          494 non-null    object
#  7   city                                     494 non-null    object
#  8   parent_organization                      494 non-null    object
#  9   global_org_url_from_parent_organization  494 non-null    object
#  10  twitter                                  494 non-null    object
#  11  github                                   494 non-null    object
#  12  website                                  494 non-null    object
#  13  meetup                                   494 non-null    object
#  14  region                                   494 non-null    object
#  15  notes                                    494 non-null    object
#  16  donate                                   494 non-null    object
# dtypes: object(17)
# memory usage: 65.7+ KB

# %%
for col in df[['name','city']]:
    df[col] = df[col].str.strip()
    print('Number of unique values in ' + str(col) +': ' + str(df[col].nunique()))
# Out:
# Number of unique values in name: 494
# Number of unique values in city: 367

# %%
# This shows where duplicates may exist
def replacements():
    unique_city = df['city'].unique().tolist()
    score_sort = [(x,) + i
                 for x in unique_city 
                 for i in process.extract(x, unique_city, scorer=fuzz.token_sort_ratio)]
    #Create a dataframe from the tuples
    similarity_sort = pd.DataFrame(score_sort, columns=['city_sort','match_sort','score_sort'])
    return similarity_sort[similarity_sort['score_sort'].between(80, 99)]

# %%
groups = replacements().groupby(by=['match_sort'])
groups.count()[groups.count()['city_sort'] >= 4]
# Out:
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
#                       city_sort  score_sort
# match_sort
# Washington D.C.               4           4
# Washington, D.C., US          4           4
# Washington, US                4           4

# %%
# Get the List and Check Against a Value
unique_list = replacements()
unique[unique_list['match_sort'].str.contains('Houston')]
# Out:
#            city_sort      match_sort  score_sort
# 281   Houston, Texas     Houston, TX          87
# 981          Houston     Houston, TX          82
# 1341     Houston, TX  Houston, Texas          87
# 1342     Houston, TX         Houston          82

# %%
def unify(df, match_series, city_sort_value):
    """given a dataframe(df) and match_series, set all values of the dataframe to the city_sort_value"""
    matcher = match_series[match_series['match_sort'] == city_sort_value]['city_sort']
    df.loc[df['city'].isin(matcher), ['city']] = city_sort_value
    return df[df['city'] == city_sort_value]

# %%
unify(df, replacements, 'Houston, TX')
# Out:
#                                               name  \
# 62                        Girl Develop It! Houston
# 170                        Houston Latinas in Tech
# 255                 Blacks in Technology - Houston
# 314                                  BUILT Houston
# 347                               PyLadies Houston
# 374  Blacks in Cybersecurity University of Houston
# 399                           Tech for the Culture
#
#                                                    url  \
# 62                           http://girldevelopit.com/
# 170      https://www.latinasintech.org/chapter/houston
# 255                 https://www.meetup.com/bithouston/
# 314  https://www.meetup.com/blacks-united-in-leadin...
# 347                    https://pyladies.com/locations/
# 374                  https://www.blacksincyberconf.com
# 399
#
#                                                  links      technology_focus  \
# 62                   [https://twitter.com/@gdihouston]     [Youth Education]
# 170                                                     [General Technology]
# 255                                                     [General Technology]
# 314  [https://www.meetup.com/blacks-united-in-leadi...  [General Technology]
# 347  [https://www.meetup.com/Houston_PyLadies/, htt...              [Python]
# 374                                                               [Security]
# 399               [https://twitter.com/@techculturetx]  [General Technology]
#
#                                      organization_logo  \
# 62   https://pbs.twimg.com/profile_images/123317612...
# 170  https://www.latinasintech.org/wp-content/uploa...
# 255  https://kjaymiller.s3-us-west-2.amazonaws.com/...
# 314  https://builtinternational.org/wp-content/uplo...
# 347  https://pyladies.com/assets/images/pylady_geek...
# 374  https://static.wixstatic.com/media/05d08c_80fb...
# 399
#
#                                            id  diversity_focus         city  \
# 62   ece4e2c91e2fe42f6ccc5bc5b33a72498ca7c013          [Women]  Houston, TX
# 170  7cbcbeffc60d73407ad573263dddeb622a04d592  [Latinx, Women]  Houston, TX
# 255  ca08bad6905889e97f1088a3a54ffc14e96c4737          [BIPOC]  Houston, TX
# 314  a1488eaa73993cea89b28162ccede9a7b983beed          [BIPOC]  Houston, TX
# 347  b966e1bcfac096984cf62f2d440caf61a56ab0ff          [Women]  Houston, TX
# 374  3e3fad5cded6fe12d4ae60e8e79d2634b679ce84          [BIPOC]  Houston, TX
# 399  86dad0c1191ca3c70cb6980e5d48d10a0bb10dad          [BIPOC]  Houston, TX
#
#                                    parent_organization  \
# 62                                    Girl Develop It!
# 170                                    Latinas in Tech
# 255                    Blacks in Technology Foundation
# 314  Blacks United in Leading Technology International
# 347                                           PyLadies
# 374                            Blacks in CyberSecurity
# 399
#
#     global_org_url_from_parent_organization twitter github website meetup  \
# 62                https://girldevelopit.com
# 170          https://www.latinasintech.org/
# 255          https://blacksintechnology.net
# 314          https://builtinternational.org
# 347                    https://pyladies.com
# 374       https://www.blacksincyberconf.com
# 399
#
#            region                                              notes donate
# 62   AMER-C-South
# 170  AMER-C-South
# 255
# 314
# 347
# 374  AMER-C-South
# 399  AMER-C-South  Reggie (One of the organizers) just recently j...
